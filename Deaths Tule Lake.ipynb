# %% [markdown]
# # A Framework for Exploring the Distriubution of Death in WWII Tule Lake Camp by Demographics

# %% [markdown]
# Creators: Quest Hollis, Sajjad Razvi, Shahin Khazaeli, Victoria Nathaniel, Mohammud Mossa

# %% [markdown]
# ## Background
#
# Around 120,000 individuals of Japanese ancestry were forcefully transported and imprisoned in concentration camps in the country’s western heartland. Approximately 2/3 of the internees were citizens of the United States [1]. The conditions of these camps were poor. Internees were kept in poorly insulated dorms with just cots and coal burning stoves. Hot water was often scarce, so residents shared bathrooms and laundry facilities. The camps were bordered by barbed-wire walls which were guarded by armed security who were instructed to kill anybody who attempted to flee. Many perished as a result of being shot, sickness, and other circumstances in the camps.
#
# ## Introduction
# For the scope of this project, our group observed the death trends of individuals in the concentration camps. The recorded data that we analyzed has summary statistics of the death certificates from WWII concentration camps. The dataset consisted of over 326 total death certificates of the individuals that died over the four-year span of World War II (1942-1946).
#
# During our exploration of this dataset, we looked into the demographics of the individuals during this time to identify any trends noticeable between those that had died. More than 18,000 Japanese Americans lived at the Tule Lake camp. Making Tule Lake camp one of the largest concentration camps. Over 300 individuals perished in Tule Lake over the course of four years. We took this data and transported it into a spreadsheet to create possible visuals of all the data. For the purpose of the research, we concentrated on the demographic distribution of those who perished in the Tule Lake camp.

# %% [markdown]
# ## Tule Lake Camp
#
# Due to the tension between the United States and Japan (The Empire of Japan) during World War II, especially after the Pearl Harbor incident on December 7, 1941, on February 19, 1942, President Franklin D. Roosevelt signed the Executive order 9066 [3].
#
#  This order authorized the Secretary of War to relocate all Japanese Americans residing on the West Coast to be interned in isolated camps, one of which is the Tule Lake Internment camp. Tule Lake camp was one of the 10 camps where Japanese Americans were incarcerated from 1942, to 1946. It was officially opened May 26, 1942 detaining Japanese Americans who lived on the West Coast from Washington, Oregon and North California.  In the camp were found hospitals, cemeteries, and farmland. Tule Lake was more like a prison-life atmosphere where Japanese Americans were forced to answer loyalty questionnaires.
#
# Due to the nature of these incidents at Tule Lake Camp, the focus of our project is to digitize all physical information available on people from this camp. By looking at death certificate records, we will be observing the death trends of each of these individuals who have passed away at this camp, along with determining the overall death tolls, age of each individual, their genders, death date, and birthplace.
#
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Primary Source of Data
# *Summary of Certificates of Death and Monthly Listings of Deaths for Tule Lake Center From The Inception of Center to Date. (Pages 93 - 111)*
#
# [link](https://umd.app.box.com/s/ey0w7yv9pakwxf4i4qlhjy3qfnkrrzhy/file/873871309399) (UMD access required)
#
# ###### Glimpse of Dataset
# *This output shows the first five rows of the dataset. The first death ceritficate listed belonged to a woman by the name of Massao Hirasawa, who died on May 18th, 1942.*

# %%
import pandas as pd
df= pd.read_excel(r'Deaths-TuleLake.xlsx')
df.head(5)
# Out:
#   Date of Death  Year of Death Last Name  First Name Sex Family Number  \
# 0     5/18/1942           1942  HIRASAWA       Masao   F         16341
# 1     6/06/1942           1942    MAFUNE     Densaku   M       172236B
# 2     6/23/1942           1942    MIYAKO       Kazuo   M         16906
# 3     7/10/1942           1942   IWASAKI  Dennis Den   M        37279F
# 4     7/18/1942           1942    FUKUDA      Kikuye   F        27336B
#
#   Age Range    Age Marital Status Birthplace Residence City Residence State
# 0     45-49     48              M          J         Fresno              CA
# 1     60-64     60              M          J        Edmonds              CA
# 2     15-19     19              S         US         Fresno              CA
# 3   Under 1  2days              S         US         Newell              CA
# 4     40-44     41              M          J     Sacramento              CA

# %% [markdown]
# ### Tableu Guide¶
# To navigate through the Tableau is simple, once prompted to each individual link. All information is shown in the dashboard. They are a collection of worksheets all combined into one story board. The information on each dashboard differs from one another by year and provides a specific breakdown once hovered over. The labels indicate what is specifically being referenced.
#
# ### Tableau Public Dashboards [link](https://public.tableau.com/views/TuleLakeCampStory-FinalProject/DeathinTuleLakeCamp?:language=en-US&publish=yes&:display_count=n&:origin=viz_share_link)
#
# * 1942 [link](https://public.tableau.com/app/profile/shahin7574/viz/Final_16390057827050/Dashboard1)
#
# * 1943 [link](https://public.tableau.com/views/Datafor1943/Dashboard2?:language=en-US&publish=yes&:display_count=n&:origin=viz_share_link)
#
# * 1944 [link](https://public.tableau.com/app/profile/victoria.nathaniel/viz/JA1944/Dashboard1?publish=yes)
#
# * 1956~1946 [link](https://public.tableau.com/app/profile/jay3623/viz/Book1_16390073437170/Dashboard1)

# %% [markdown]
# ## Software and Tools
# * Tableau
# * Microsoft Excel
# * Jupyter NoteBook

# %% [markdown]
# ### References
#
# [1] Encyclopædia Britannica, inc. (n.d.). Japanese American internment. Encyclopædia Britannica.
# Retrieved December 16, 2021, from https://www.britannica.com/event/Japanese-American-internment
#
# [2] Tule Lake (U.S. National Park Service). (n.d.). Www.nps.gov. Retrieved December 16, 2021,
# from https://www.nps.gov/places/tule-lake.htm
#
# [3] Executive order 9066: Resulting in the relocation of Japanese (1942). Our Documents - Executive Order 9066: Resulting in the Relocation of Japanese (1942). (n.d.). Retrieved December 16, 2021, from https://www.ourdocuments.gov/doc.php?flash=false&doc=74
